# %%
dev = "masukkan youtube API Key"

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="nsZ9AB_bjSA",
    maxResults=1485
)

comments = []

# Execute the request.
response = request.execute()

# Get the comments from the response.
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

while (1 == 1):
  try:
   nextPageToken = response['nextPageToken']
  except KeyError:
   break
  nextPageToken = response['nextPageToken']
  # Create a new request object with the next page token.
  nextRequest = youtube.commentThreads().list(part="snippet", videoId="-GJgqIJsTME", maxResults=100, pageToken=nextPageToken)
  # Execute the next request.
  response = nextRequest.execute()
  # Get the comments from the next response.
  for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

df = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','public'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 793 entries, 0 to 792
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   author      793 non-null    object
#  1   updated_at  793 non-null    object
#  2   like_count  793 non-null    int64
#  3   text        793 non-null    object
#  4   public      793 non-null    bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 25.7+ KB

# %%
response['items'][0]
# Out:
# {'kind': 'youtube#commentThread',
#  'etag': 'wmt4qkWp1nhxWftvGbcJZ6eVcJk',
#  'id': 'UgwAPGikuoPCU8xUOtN4AaABAg',
#  'snippet': {'channelId': 'UC2utQmYluWGlhV-W0rTA2wg',
#   'videoId': '-GJgqIJsTME',
#   'topLevelComment': {'kind': 'youtube#comment',
#    'etag': 'qs0bffW_z6lfA7dyaXCVaqCekh8',
#    'id': 'UgwAPGikuoPCU8xUOtN4AaABAg',
#    'snippet': {'channelId': 'UC2utQmYluWGlhV-W0rTA2wg',
#     'videoId': '-GJgqIJsTME',
#     'textDisplay': 'Clovis I love you but see a dentist',
#     'textOriginal': 'Clovis I love you but see a dentist',
#     'authorDisplayName': '@chef_benny',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZTZkCrurUNuVM77c8q9sbHSJOdvsE6NVGVdd3iF4MkaTUoVoxnT3uj0HMvaKgen=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/channel/UC3hnSpqSJbcaVVr85bZnxHQ',
#     'authorChannelId': {'value': 'UC3hnSpqSJbcaVVr85bZnxHQ'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 1,
#     'publishedAt': '2023-10-23T16:38:04Z',
#     'updatedAt': '2023-10-23T16:38:04Z'}},
#   'canReply': True,
#   'totalReplyCount': 0,
#   'isPublic': True}}

# %%
df.head(1485)
# Out:
#                               author            updated_at  like_count  \
# 0                      @riyanti_8621  2024-01-09T14:08:55Z           2
# 1           @widyaudriana_Lasagnakyu  2024-01-09T14:01:26Z           2
# 2                      @iningsri9226  2024-01-09T14:00:40Z           2
# 3                        @walena2345  2024-01-09T13:40:38Z           2
# 4                   @fujanoviansah91  2024-01-09T13:01:24Z           2
# ..                               ...                   ...         ...
# 788                      @SamB-ij1ko  2023-10-23T13:34:12Z           0
# 789                          @ec6678  2023-10-23T13:33:21Z          13
# 790                       @cheng8841  2023-10-23T12:57:25Z          66
# 791                   @BigTunaBoy420  2023-10-23T12:30:09Z         268
# 792  @cccccccccccccccccccccccccc8412  2023-10-23T12:30:02Z           0
#
#                                                   text  public
# 0    Ciee nungguin yaa..🙈bru syuting shooping prlgk...    True
# 1          MasyaAllah keren nya ada air d tengah” rmh😍    True
# 2                 Alhamdulilah pindah kerumah baru ❤❤❤    True
# 3                   Alhamdulillah..\nSenangnya KK naa❤    True
# 4                                             Kereeenn    True
# ..                                                 ...     ...
# 788                                   Buzzing for this    True
# 789                       Watch out for those bed bugs    True
# 790                   "eight part series" LETS GOOOOOO    True
# 791    One of the best and most authentic eating shows    True
# 792                                              First    True
#
# [793 rows x 5 columns]

# %%
df.sort_values(by='like_count', ascending=False)[0:100]
# Out:
#                      author            updated_at  like_count  \
# 777             @dirtsmegee  2023-10-23T15:05:53Z        1042
# 680          @Nolanbrown480  2023-10-23T16:59:11Z         708
# 645     @ActionBronsonMusic  2023-10-23T17:53:02Z         573
# 782         @uknownutin3528  2023-10-23T15:01:03Z         507
# 791          @BigTunaBoy420  2023-10-23T12:30:09Z         268
# ..                      ...                   ...         ...
# 70    @KusanahKusanah-ts7xs  2024-01-08T13:52:12Z           3
# 437               @jeejbeej  2023-10-24T09:07:35Z           3
# 56           @ettyakbar1793  2024-01-08T18:24:30Z           3
# 27   @StrawberryMochi-tm1em  2024-01-09T07:06:02Z           3
# 775        @otizoctopus4204  2023-10-23T15:06:38Z           3
#
#                                                   text  public
# 777  Action needs an 8 part series in every country...    True
# 680  Clovis’ energy is absolutely unmatched. The pe...    True
# 645                                  PARIS. WITH LOVE.    True
# 782  One of the best food series on YouTube. LONG L...    True
# 791    One of the best and most authentic eating shows    True
# ..                                                 ...     ...
# 70   Alhamdulillah semoga sll di mudahkan urusan du...    True
# 437  This is amazing, I was a bit worried it could ...    True
# 56           Alhamdulillah,dah pindahan.TheAttaFamily.    True
# 27   Yang nyinyirin aurel kemarin bisa gini gak ya ? 😂    True
# 775  I love the show action keep up the good work b...    True
#
# [100 rows x 5 columns]

# %%
df.to_excel("komentaryoutube_baru.xlsx",
             sheet_name='Sheet_name_1')
